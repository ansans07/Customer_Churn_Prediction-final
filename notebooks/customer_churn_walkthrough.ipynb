# %% [markdown]
# # Customer Churn Prediction - Notebook
# This notebook gives a simple walkthrough of the project workflow. The full reusable code is inside the `src/` folder.

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path("../data/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df = pd.read_csv(DATA_PATH)
df.head()

# %%
df.shape, df.info()

# %%
df["Churn"].value_counts(normalize=True)

# %% [markdown]
# ## Run the full training pipeline
# Run this command from the project root terminal:
#
# ```bash
# python src/train.py
# ```

# %%
pd.read_csv("../reports/model_comparison.csv") if Path("../reports/model_comparison.csv").exists() else "Run python src/train.py first"
